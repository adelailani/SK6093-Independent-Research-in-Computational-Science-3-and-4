# %% [markdown]
# Monitoring Penyebaran Covid 19 pada Area Publik dengan Convolution Neural Networks (CNN)
#
#
# # SK6093-Independent Research in Computational Science 3 :
# ## Sistem Deteksi Masker Wajah pada Area Publik Menggunakan Convolution Neural Networks
#
# Oleh:
# Ade Lailani (20920003)

# %% [markdown]
# ### Abstrak
# Pada penelitian ini kami akan membuat model pendeteksi masker dengan Convolutional Neural Network.
# Adapun tujuan dalam penelitian adalah untuk mengklasifikasikan foto wajah yang akan kita bagi datanya menjadi dua kelas, sehingga kita dapat menjawab pertanyaan berikut.
#
# Apakah orang itu memakai masker atau tidak?
#
# Sistem deteksi masker (Face mask detection) dengan menggunakan pengolahan citra dilakukan juga untuk mengetahui besar akurasi dari metode Convolution Neural Networks (CNN) yang digunakan.

# %% [markdown]
# ### Langkah 1 : Pengumpulan Data

# %% [markdown]
# Dataset : https://www.kaggle.com/omkargurav/face-mask-dataset
#
# Dataset berukuran 160 MB, berisi 7553 foto dengan 3-channel jpg extension (RGB). Dataset tersebut terdiri dari 3725 foto wajah dengan masker dan 3828 foto wajah tanpa masker dengan berbagai ukuran foto.

# %% [markdown]
# ### Langkah 2 : Split Data

# %%
import os
import shutil

# mengakses dataset awal
data_dir = 'data'

# membuat informasi class
all_class = {'train':{},'valid':{}}
for cl in os.listdir(data_dir):
    items = os.listdir(f'{data_dir}/{cl}')
    test_count = int(0.2*(len(items)))
    all_class['train'][cl] = items[test_count:]
    all_class['valid'][cl] = items[:test_count]

# %%
# memindahkan file dataset awal ke folder baru 
for category,cl in all_class.items():
    for sub_class,item in cl.items():
        for i in item:
            print(f'{category}/{sub_class}/{i}')
            des_path = f'dataset/{category}/{sub_class}/'
            os.makedirs(des_path, exist_ok=True)
            shutil.move(f'{data_dir}/{sub_class}/{i}',des_path)

# %% [markdown]
# Selanjutnya, kita perlu mengimpor semua pustaka yang diperlukan.
#
# Definisikan loading_data()fungsi untuk mengulang direktori untuk memasukkan semua direktori file ke dalam daftar python.

# %%
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
keras = tf.keras

# %%
def loading_data():
    dirname = 'dataset/'
    dirtype = ['train/', 'valid/']
    dirclass = ['with_mask/', 'without_mask/']
    
    x_train = []
    y_train = []
    x_test = []
    y_test = []
    
    for typ in dirtype:
        for cls in dirclass:
            for i in os.listdir(dirname+typ+cls):
                if typ == 'train/':
                    x_train.append(dirname+'train/'+cls+i)
                    y_train.append(cls[:-1])
                else:
                    x_test.append(dirname+'valid/'+cls+i)
                    y_test.append(cls[:-1])
    return np.array(x_train),np.array(y_train),np.array(x_test),np.array(y_test)


# Run loading_data() function
x_train,y_train,x_test,y_test = loading_data()

# %% [markdown]
# mengekstrak file zip, Refactor direktori menjadi terlihat seperti ini.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Langkah 3 : Data Preprocessing

# %% [markdown]
# untuk meningkatkan kinerja model dan menghindari overfitting dapat dilakukan flipping, rotating, cropping, zooming, and shifting the image position.
#
# Karena gambar kita memilki ukuran yang berbeda beda maka kita resize
# setiap gambar menjadi 224,224.
#
# kami menggunakan input output Tensorflow tf.io.read_file(path) karena kami ingin membuat batch data sebelum melatih model, sehingga proses pelatihan dapat berjalan lebih cepat.

# %%
# Processing image files into numpy array
def process_label(label):
    label = [i == unique_label for i in label]
    label = np.array(label).astype(int)
    return label
  
def processImage(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image,channels=3)
    image = tf.image.convert_image_dtype(image,tf.float32)
    image = tf.image.resize(image,size=[224,224])
    return image

# Create Batch data of numpy array
def pairData(image,label):
    return processImage(image),label
  
def batchData(image,label=None,for_valid=False,for_test=False):
    if for_test:
        data = tf.data.Dataset.from_tensor_slices((image))
        batch = data.map(processImage).batch(32)
        return batch
    elif for_valid:
        data = tf.data.Dataset.from_tensor_slices((tf.constant(image),tf.constant(label)))
        batch = data.map(pairData).batch(32)
        return batch
    else:
        data = tf.data.Dataset.from_tensor_slices((tf.constant(image),tf.constant(label)))
        data = data.shuffle(buffer_size=len(image))
        batch = data.map(pairData).batch(32)
        return batch
  
unique_label = np.unique(y_test)
y_test = process_label(y_test)
y_train = process_label(y_train)

train_data = batchData(x_train,y_train)
valid_data = batchData(x_test,y_test,for_valid=True)

# %%
x_train,y_train,x_test,y_test = loading_data()

# %%
x_train,x_test
# Out:
# (array(['dataset/train/with_mask/with_mask_1557.jpg',
#         'dataset/train/with_mask/with_mask_1558.jpg',
#         'dataset/train/with_mask/with_mask_1559.jpg', ...,
#         'dataset/train/without_mask/without_mask_997.jpg',
#         'dataset/train/without_mask/without_mask_998.jpg',
#         'dataset/train/without_mask/without_mask_999.jpg'], dtype='<U48'),
#  array(['dataset/valid/with_mask/with_mask_1.jpg',
#         'dataset/valid/with_mask/with_mask_10.jpg',
#         'dataset/valid/with_mask/with_mask_100.jpg',
#         'dataset/valid/with_mask/with_mask_1000.jpg',
#         'dataset/valid/with_mask/with_mask_1001.jpg',
#         'dataset/valid/with_mask/with_mask_1002.jpg',
#         'dataset/valid/with_mask/with_mask_1003.jpg',
#         'dataset/valid/with_mask/with_mask_1004.jpg',
#         'dataset/valid/with_mask/with_mask_1005.jpg',
#         'dataset/valid/with_mask/with_mask_1006.jpg',
#         'dataset/valid/with_mask/with_mask_1007.jpg',
#         'dataset/valid/with_mask/with_mask_1008.jpg',
#         'dataset/valid/with_mask/with_mask_1009.jpg',
#         'dataset/valid/with_mask/with_mask_101.jpg',
#         'dataset/valid/with_mask/with_mask_1010.jpg',
#         'dataset/valid/with_mask/with_mask_1011.jpg',
#         'dataset/valid/with_mask/with_mask_1012.jpg',
#         'dataset/valid/with_mask/with_mask_1013.jpg',
#         'dataset/valid/with_mask/with_mask_1014.jpg',
#         'dataset/valid/with_mask/with_mask_1015.jpg',
#         'dataset/valid/with_mask/with_mask_1016.jpg',
#         'dataset/valid/with_mask/with_mask_1017.jpg',
#         'dataset/valid/with_mask/with_mask_1018.jpg',
#         'dataset/valid/with_mask/with_mask_1019.jpg',
#         'dataset/valid/with_mask/with_mask_102.jpg',
#         'dataset/valid/with_mask/with_mask_1020.jpg',
#         'dataset/valid/with_mask/with_mask_1021.jpg',
#         'dataset/valid/with_mask/with_mask_1022.jpg',
#         'dataset/valid/with_mask/with_mask_1023.jpg',
#         'dataset/valid/with_mask/with_mask_1024.jpg',
#         'dataset/valid/with_mask/with_mask_1025.jpg',
#         'dataset/valid/with_mask/with_mask_1026.jpg',
#         'dataset/valid/with_mask/with_mask_1027.jpg',
#         'dataset/valid/with_mask/with_mask_1028.jpg',
#         'dataset/valid/with_mask/with_mask_1029.jpg',
#         'dataset/valid/with_mask/with_mask_103.jpg',
#         'dataset/valid/with_mask/with_mask_1030.jpg',
#         'dataset/valid/with_mask/with_mask_1031.jpg',
#         'dataset/valid/with_mask/with_mask_1032.jpg',
#         'dataset/valid/with_mask/with_mask_1033.jpg',
#         'dataset/valid/with_mask/with_mask_1034.jpg',
#         'dataset/valid/with_mask/with_mask_1035.jpg',
#         'dataset/valid/with_mask/with_mask_1036.jpg',
#         'dataset/valid/with_mask/with_mask_1037.jpg',
#         'dataset/valid/with_mask/with_mask_1038.jpg',
#         'dataset/valid/with_mask/with_mask_1039.jpg',
#         'dataset/valid/with_mask/with_mask_104.jpg',
#         'dataset/valid/with_mask/with_mask_1040.jpg',
#         'dataset/valid/with_mask/with_mask_1041.jpg',
#         'dataset/valid/with_mask/with_mask_1042.jpg',
#         'dataset/valid/with_mask/with_mask_1043.jpg',
#         'dataset/valid/with_mask/with_mask_1044.jpg',
#         'dataset/valid/with_mask/with_mask_1045.jpg',
#         'dataset/valid/with_mask/with_mask_1046.jpg',
#         'dataset/valid/with_mask/with_mask_1047.jpg',
#         'dataset/valid/with_mask/with_mask_1048.jpg',
#         'dataset/valid/with_mask/with_mask_1049.jpg',
#         'dataset/valid/with_mask/with_mask_105.jpg',
#         'dataset/valid/with_mask/with_mask_1050.jpg',
#         'dataset/valid/with_mask/with_mask_1051.jpg',
#         'dataset/valid/with_mask/with_mask_1052.jpg',
#         'dataset/valid/with_mask/with_mask_1053.jpg',
#         'dataset/valid/with_mask/with_mask_1054.jpg',
#         'dataset/valid/with_mask/with_mask_1055.jpg',
#         'dataset/valid/with_mask/with_mask_1056.jpg',
#         'dataset/valid/with_mask/with_mask_1057.jpg',
#         'dataset/valid/with_mask/with_mask_1058.jpg',
#         'dataset/valid/with_mask/with_mask_1059.jpg',
#         'dataset/valid/with_mask/with_mask_106.jpg',
#         'dataset/valid/with_mask/with_mask_1060.jpg',
#         'dataset/valid/with_mask/with_mask_1061.jpg',
#         'dataset/valid/with_mask/with_mask_1062.jpg',
#         'dataset/valid/with_mask/with_mask_1063.jpg',
#         'dataset/valid/with_mask/with_mask_1064.jpg',
#         'dataset/valid/with_mask/with_mask_1065.jpg',
#         'dataset/valid/with_mask/with_mask_1066.jpg',
#         'dataset/valid/with_mask/with_mask_1067.jpg',
#         'dataset/valid/with_mask/with_mask_1068.jpg',
#         'dataset/valid/with_mask/with_mask_1069.jpg',
#         'dataset/valid/with_mask/with_mask_107.jpg',
#         'dataset/valid/with_mask/with_mask_1070.jpg',
#         'dataset/valid/with_mask/with_mask_1071.jpg',
#         'dataset/valid/with_mask/with_mask_1072.jpg',
#         'dataset/valid/with_mask/with_mask_1073.jpg',
#         'dataset/valid/with_mask/with_mask_1074.jpg',
#         'dataset/valid/with_mask/with_mask_1075.jpg',
#         'dataset/valid/with_mask/with_mask_1076.jpg',
#         'dataset/valid/with_mask/with_mask_1077.jpg',
#         'dataset/valid/with_mask/with_mask_1078.jpg',
#         'dataset/valid/with_mask/with_mask_1079.jpg',
#         'dataset/valid/with_mask/with_mask_108.jpg',
#         'dataset/valid/with_mask/with_mask_1080.jpg',
#         'dataset/valid/with_mask/with_mask_1081.jpg',
#         'dataset/valid/with_mask/with_mask_1082.jpg',
#         'dataset/valid/with_mask/with_mask_1083.jpg',
#         'dataset/valid/with_mask/with_mask_1084.jpg',
#         'dataset/valid/with_mask/with_mask_1085.jpg',
#         'dataset/valid/with_mask/with_mask_1086.jpg',
#         'dataset/valid/with_mask/with_mask_1087.jpg',
#         'dataset/valid/with_mask/with_mask_1088.jpg',
#         'dataset/valid/with_mask/with_mask_1089.jpg',
#         'dataset/valid/with_mask/with_mask_109.jpg',
#         'dataset/valid/with_mask/with_mask_1090.jpg',
#         'dataset/valid/with_mask/with_mask_1091.jpg',
#         'dataset/valid/with_mask/with_mask_1092.jpg',
#         'dataset/valid/with_mask/with_mask_1093.jpg',
#         'dataset/valid/with_mask/with_mask_1094.jpg',
#         'dataset/valid/with_mask/with_mask_1095.jpg',
#         'dataset/valid/with_mask/with_mask_1096.jpg',
#         'dataset/valid/with_mask/with_mask_1097.jpg',
#         'dataset/valid/with_mask/with_mask_1098.jpg',
#         'dataset/valid/with_mask/with_mask_1099.jpg',
#         'dataset/valid/with_mask/with_mask_11.jpg',
#         'dataset/valid/with_mask/with_mask_110.jpg',
#         'dataset/valid/with_mask/with_mask_1100.jpg',
#         'dataset/valid/with_mask/with_mask_1101.jpg',
#         'dataset/valid/with_mask/with_mask_1102.jpg',
#         'dataset/valid/with_mask/with_mask_1103.jpg',
#         'dataset/valid/with_mask/with_mask_1104.jpg',
#         'dataset/valid/with_mask/with_mask_1105.jpg',
#         'dataset/valid/with_mask/with_mask_1106.jpg',
#         'dataset/valid/with_mask/with_mask_1107.jpg',
#         'dataset/valid/with_mask/with_mask_1108.jpg',
#         'dataset/valid/with_mask/with_mask_1109.jpg',
#         'dataset/valid/with_mask/with_mask_111.jpg',
#         'dataset/valid/with_mask/with_mask_1110.jpg',
#         'dataset/valid/with_mask/with_mask_1111.jpg',
#         'dataset/valid/with_mask/with_mask_1112.jpg',
#         'dataset/valid/with_mask/with_mask_1113.jpg',
#         'dataset/valid/with_mask/with_mask_1114.jpg',
#         'dataset/valid/with_mask/with_mask_1115.jpg',
#         'dataset/valid/with_mask/with_mask_1116.jpg',
#         'dataset/valid/with_mask/with_mask_1117.jpg',
#         'dataset/valid/with_mask/with_mask_1118.jpg',
#         'dataset/valid/with_mask/with_mask_1119.jpg',
#         'dataset/valid/with_mask/with_mask_112.jpg',
#         'dataset/valid/with_mask/with_mask_1120.jpg',
#         'dataset/valid/with_mask/with_mask_1121.jpg',
#         'dataset/valid/with_mask/with_mask_1122.jpg',
#         'dataset/valid/with_mask/with_mask_1123.jpg',
#         'dataset/valid/with_mask/with_mask_1124.jpg',
#         'dataset/valid/with_mask/with_mask_1125.jpg',
#         'dataset/valid/with_mask/with_mask_1126.jpg',
#         'dataset/valid/with_mask/with_mask_1127.jpg',
#         'dataset/valid/with_mask/with_mask_1128.jpg',
#         'dataset/valid/with_mask/with_mask_1129.jpg',
#         'dataset/valid/with_mask/with_mask_113.jpg',
#         'dataset/valid/with_mask/with_mask_1130.jpg',
#         'dataset/valid/with_mask/with_mask_1131.jpg',
#         'dataset/valid/with_mask/with_mask_1132.jpg',
#         'dataset/valid/with_mask/with_mask_1133.jpg',
#         'dataset/valid/with_mask/with_mask_1134.jpg',
#         'dataset/valid/with_mask/with_mask_1135.jpg',
#         'dataset/valid/with_mask/with_mask_1136.jpg',
#         'dataset/valid/with_mask/with_mask_1137.jpg',
#         'dataset/valid/with_mask/with_mask_1138.jpg',
#         'dataset/valid/with_mask/with_mask_1139.jpg',
#         'dataset/valid/with_mask/with_mask_114.jpg',
#         'dataset/valid/with_mask/with_mask_1140.jpg',
#         'dataset/valid/with_mask/with_mask_1141.jpg',
#         'dataset/valid/with_mask/with_mask_1142.jpg',
#         'dataset/valid/with_mask/with_mask_1143.jpg',
#         'dataset/valid/with_mask/with_mask_1144.jpg',
#         'dataset/valid/with_mask/with_mask_1145.jpg',
#         'dataset/valid/with_mask/with_mask_1146.jpg',
#         'dataset/valid/with_mask/with_mask_1147.jpg',
#         'dataset/valid/with_mask/with_mask_1148.jpg',
#         'dataset/valid/with_mask/with_mask_1149.jpg',
#         'dataset/valid/with_mask/with_mask_115.jpg',
#         'dataset/valid/with_mask/with_mask_1150.jpg',
#         'dataset/valid/with_mask/with_mask_1151.jpg',
#         'dataset/valid/with_mask/with_mask_1152.jpg',
#         'dataset/valid/with_mask/with_mask_1153.jpg',
#         'dataset/valid/with_mask/with_mask_1154.jpg',
#         'dataset/valid/with_mask/with_mask_1155.jpg',
#         'dataset/valid/with_mask/with_mask_1156.jpg',
#         'dataset/valid/with_mask/with_mask_1157.jpg',
#         'dataset/valid/with_mask/with_mask_1158.jpg',
#         'dataset/valid/with_mask/with_mask_1159.jpg',
#         'dataset/valid/with_mask/with_mask_116.jpg',
#         'dataset/valid/with_mask/with_mask_1160.jpg',
#         'dataset/valid/with_mask/with_mask_1161.jpg',
#         'dataset/valid/with_mask/with_mask_1162.jpg',
#         'dataset/valid/with_mask/with_mask_1163.jpg',
#         'dataset/valid/with_mask/with_mask_1164.jpg',
#         'dataset/valid/with_mask/with_mask_1165.jpg',
#         'dataset/valid/with_mask/with_mask_1166.jpg',
#         'dataset/valid/with_mask/with_mask_1167.jpg',
#         'dataset/valid/with_mask/with_mask_1168.jpg',
#         'dataset/valid/with_mask/with_mask_1169.jpg',
#         'dataset/valid/with_mask/with_mask_117.jpg',
#         'dataset/valid/with_mask/with_mask_1170.jpg',
#         'dataset/valid/with_mask/with_mask_1171.jpg',
#         'dataset/valid/with_mask/with_mask_1172.jpg',
#         'dataset/valid/with_mask/with_mask_1173.jpg',
#         'dataset/valid/with_mask/with_mask_1174.jpg',
#         'dataset/valid/with_mask/with_mask_1175.jpg',
#         'dataset/valid/with_mask/with_mask_1176.jpg',
#         'dataset/valid/with_mask/with_mask_1177.jpg',
#         'dataset/valid/with_mask/with_mask_1178.jpg',
#         'dataset/valid/with_mask/with_mask_1179.jpg',
#         'dataset/valid/with_mask/with_mask_118.jpg',
#         'dataset/valid/with_mask/with_mask_1180.jpg',
#         'dataset/valid/with_mask/with_mask_1181.jpg',
#         'dataset/valid/with_mask/with_mask_1182.jpg',
#         'dataset/valid/with_mask/with_mask_1183.jpg',
#         'dataset/valid/with_mask/with_mask_1184.jpg',
#         'dataset/valid/with_mask/with_mask_1185.jpg',
#         'dataset/valid/with_mask/with_mask_1186.jpg',
#         'dataset/valid/with_mask/with_mask_1187.jpg',
#         'dataset/valid/with_mask/with_mask_1188.jpg',
#         'dataset/valid/with_mask/with_mask_1189.jpg',
#         'dataset/valid/with_mask/with_mask_119.jpg',
#         'dataset/valid/with_mask/with_mask_1190.jpg',
#         'dataset/valid/with_mask/with_mask_1191.jpg',
#         'dataset/valid/with_mask/with_mask_1192.jpg',
#         'dataset/valid/with_mask/with_mask_1193.jpg',
#         'dataset/valid/with_mask/with_mask_1194.jpg',
#         'dataset/valid/with_mask/with_mask_1195.jpg',
#         'dataset/valid/with_mask/with_mask_1196.jpg',
#         'dataset/valid/with_mask/with_mask_1197.jpg',
#         'dataset/valid/with_mask/with_mask_1198.jpg',
#         'dataset/valid/with_mask/with_mask_1199.jpg',
#         'dataset/valid/with_mask/with_mask_12.jpg',
#         'dataset/valid/with_mask/with_mask_120.jpg',
#         'dataset/valid/with_mask/with_mask_1200.jpg',
#         'dataset/valid/with_mask/with_mask_1201.jpg',
#         'dataset/valid/with_mask/with_mask_1202.jpg',
#         'dataset/valid/with_mask/with_mask_1203.jpg',
#         'dataset/valid/with_mask/with_mask_1204.jpg',
#         'dataset/valid/with_mask/with_mask_1205.jpg',
#         'dataset/valid/with_mask/with_mask_1206.jpg',
#         'dataset/valid/with_mask/with_mask_1207.jpg',
#         'dataset/valid/with_mask/with_mask_1208.jpg',
#         'dataset/valid/with_mask/with_mask_1209.jpg',
#         'dataset/valid/with_mask/with_mask_121.jpg',
#         'dataset/valid/with_mask/with_mask_1210.jpg',
#         'dataset/valid/with_mask/with_mask_1211.jpg',
#         'dataset/valid/with_mask/with_mask_1212.jpg',
#         'dataset/valid/with_mask/with_mask_1213.jpg',
#         'dataset/valid/with_mask/with_mask_1214.jpg',
#         'dataset/valid/with_mask/with_mask_1215.jpg',
#         'dataset/valid/with_mask/with_mask_1216.jpg',
#         'dataset/valid/with_mask/with_mask_1217.jpg',
#         'dataset/valid/with_mask/with_mask_1218.jpg',
#         'dataset/valid/with_mask/with_mask_1219.jpg',
#         'dataset/valid/with_mask/with_mask_122.jpg',
#         'dataset/valid/with_mask/with_mask_1220.jpg',
#         'dataset/valid/with_mask/with_mask_1221.jpg',
#         'dataset/valid/with_mask/with_mask_1222.jpg',
#         'dataset/valid/with_mask/with_mask_1223.jpg',
#         'dataset/valid/with_mask/with_mask_1224.jpg',
#         'dataset/valid/with_mask/with_mask_1225.jpg',
#         'dataset/valid/with_mask/with_mask_1226.jpg',
#         'dataset/valid/with_mask/with_mask_1227.jpg',
#         'dataset/valid/with_mask/with_mask_1228.jpg',
#         'dataset/valid/with_mask/with_mask_1229.jpg',
#         'dataset/valid/with_mask/with_mask_123.jpg',
#         'dataset/valid/with_mask/with_mask_1230.jpg',
#         'dataset/valid/with_mask/with_mask_1231.jpg',
#         'dataset/valid/with_mask/with_mask_1232.jpg',
#         'dataset/valid/with_mask/with_mask_1233.jpg',
#         'dataset/valid/with_mask/with_mask_1234.jpg',
#         'dataset/valid/with_mask/with_mask_1235.jpg',
#         'dataset/valid/with_mask/with_mask_1236.jpg',
#         'dataset/valid/with_mask/with_mask_1237.jpg',
#         'dataset/valid/with_mask/with_mask_1238.jpg',
#         'dataset/valid/with_mask/with_mask_1239.jpg',
#         'dataset/valid/with_mask/with_mask_124.jpg',
#         'dataset/valid/with_mask/with_mask_1240.jpg',
#         'dataset/valid/with_mask/with_mask_1241.jpg',
#         'dataset/valid/with_mask/with_mask_1242.jpg',
#         'dataset/valid/with_mask/with_mask_1243.jpg',
#         'dataset/valid/with_mask/with_mask_1244.jpg',
#         'dataset/valid/with_mask/with_mask_1245.jpg',
#         'dataset/valid/with_mask/with_mask_1246.jpg',
#         'dataset/valid/with_mask/with_mask_1247.jpg',
#         'dataset/valid/with_mask/with_mask_1248.jpg',
#         'dataset/valid/with_mask/with_mask_1249.jpg',
#         'dataset/valid/with_mask/with_mask_125.jpg',
#         'dataset/valid/with_mask/with_mask_1250.jpg',
#         'dataset/valid/with_mask/with_mask_1251.jpg',
#         'dataset/valid/with_mask/with_mask_1252.jpg',
#         'dataset/valid/with_mask/with_mask_1253.jpg',
#         'dataset/valid/with_mask/with_mask_1254.jpg',
#         'dataset/valid/with_mask/with_mask_1255.jpg',
#         'dataset/valid/with_mask/with_mask_1256.jpg',
#         'dataset/valid/with_mask/with_mask_1257.jpg',
#         'dataset/valid/with_mask/with_mask_1258.jpg',
#         'dataset/valid/with_mask/with_mask_1259.jpg',
#         'dataset/valid/with_mask/with_mask_126.jpg',
#         'dataset/valid/with_mask/with_mask_1260.jpg',
#         'dataset/valid/with_mask/with_mask_1261.jpg',
#         'dataset/valid/with_mask/with_mask_1262.jpg',
#         'dataset/valid/with_mask/with_mask_1263.jpg',
#         'dataset/valid/with_mask/with_mask_1264.jpg',
#         'dataset/valid/with_mask/with_mask_1265.jpg',
#         'dataset/valid/with_mask/with_mask_1266.jpg',
#         'dataset/valid/with_mask/with_mask_1267.jpg',
#         'dataset/valid/with_mask/with_mask_1268.jpg',
#         'dataset/valid/with_mask/with_mask_1269.jpg',
#         'dataset/valid/with_mask/with_mask_127.jpg',
#         'dataset/valid/with_mask/with_mask_1270.jpg',
#         'dataset/valid/with_mask/with_mask_1271.jpg',
#         'dataset/valid/with_mask/with_mask_1272.jpg',
#         'dataset/valid/with_mask/with_mask_1273.jpg',
#         'dataset/valid/with_mask/with_mask_1274.jpg',
#         'dataset/valid/with_mask/with_mask_1275.jpg',
#         'dataset/valid/with_mask/with_mask_1276.jpg',
#         'dataset/valid/with_mask/with_mask_1277.jpg',
#         'dataset/valid/with_mask/with_mask_1278.jpg',
#         'dataset/valid/with_mask/with_mask_1279.jpg',
#         'dataset/valid/with_mask/with_mask_128.jpg',
#         'dataset/valid/with_mask/with_mask_1280.jpg',
#         'dataset/valid/with_mask/with_mask_1281.jpg',
#         'dataset/valid/with_mask/with_mask_1282.jpg',
#         'dataset/valid/with_mask/with_mask_1283.jpg',
#         'dataset/valid/with_mask/with_mask_1284.jpg',
#         'dataset/valid/with_mask/with_mask_1285.jpg',
#         'dataset/valid/with_mask/with_mask_1286.jpg',
#         'dataset/valid/with_mask/with_mask_1287.jpg',
#         'dataset/valid/with_mask/with_mask_1288.jpg',
#         'dataset/valid/with_mask/with_mask_1289.jpg',
#         'dataset/valid/with_mask/with_mask_129.jpg',
#         'dataset/valid/with_mask/with_mask_1290.jpg',
#         'dataset/valid/with_mask/with_mask_1291.jpg',
#         'dataset/valid/with_mask/with_mask_1292.jpg',
#         'dataset/valid/with_mask/with_mask_1293.jpg',
#         'dataset/valid/with_mask/with_mask_1294.jpg',
#         'dataset/valid/with_mask/with_mask_1295.jpg',
#         'dataset/valid/with_mask/with_mask_1296.jpg',
#         'dataset/valid/with_mask/with_mask_1297.jpg',
#         'dataset/valid/with_mask/with_mask_1298.jpg',
#         'dataset/valid/with_mask/with_mask_1299.jpg',
#         'dataset/valid/with_mask/with_mask_13.jpg',
#         'dataset/valid/with_mask/with_mask_130.jpg',
#         'dataset/valid/with_mask/with_mask_1300.jpg',
#         'dataset/valid/with_mask/with_mask_1301.jpg',
#         'dataset/valid/with_mask/with_mask_1302.jpg',
#         'dataset/valid/with_mask/with_mask_1303.jpg',
#         'dataset/valid/with_mask/with_mask_1304.jpg',
#         'dataset/valid/with_mask/with_mask_1305.jpg',
#         'dataset/valid/with_mask/with_mask_1306.jpg',
#         'dataset/valid/with_mask/with_mask_1307.jpg',
#         'dataset/valid/with_mask/with_mask_1308.jpg',
#         'dataset/valid/with_mask/with_mask_1309.jpg',
#         'dataset/valid/with_mask/with_mask_131.jpg',
#         'dataset/valid/with_mask/with_mask_1310.jpg',
#         'dataset/valid/with_mask/with_mask_1311.jpg',
#         'dataset/valid/with_mask/with_mask_1312.jpg',
#         'dataset/valid/with_mask/with_mask_1313.jpg',
#         'dataset/valid/with_mask/with_mask_1314.jpg',
#         'dataset/valid/with_mask/with_mask_1315.jpg',
#         'dataset/valid/with_mask/with_mask_1316.jpg',
#         'dataset/valid/with_mask/with_mask_1317.jpg',
#         'dataset/valid/with_mask/with_mask_1318.jpg',
#         'dataset/valid/with_mask/with_mask_1319.jpg',
#         'dataset/valid/with_mask/with_mask_132.jpg',
#         'dataset/valid/with_mask/with_mask_1320.jpg',
#         'dataset/valid/with_mask/with_mask_1321.jpg',
#         'dataset/valid/with_mask/with_mask_1322.jpg',
#         'dataset/valid/with_mask/with_mask_1323.jpg',
#         'dataset/valid/with_mask/with_mask_1324.jpg',
#         'dataset/valid/with_mask/with_mask_1325.jpg',
#         'dataset/valid/with_mask/with_mask_1326.jpg',
#         'dataset/valid/with_mask/with_mask_1327.jpg',
#         'dataset/valid/with_mask/with_mask_1328.jpg',
#         'dataset/valid/with_mask/with_mask_1329.jpg',
#         'dataset/valid/with_mask/with_mask_133.jpg',
#         'dataset/valid/with_mask/with_mask_1330.jpg',
#         'dataset/valid/with_mask/with_mask_1331.jpg',
#         'dataset/valid/with_mask/with_mask_1332.jpg',
#         'dataset/valid/with_mask/with_mask_1333.jpg',
#         'dataset/valid/with_mask/with_mask_1334.jpg',
#         'dataset/valid/with_mask/with_mask_1335.jpg',
#         'dataset/valid/with_mask/with_mask_1336.jpg',
#         'dataset/valid/with_mask/with_mask_1337.jpg',
#         'dataset/valid/with_mask/with_mask_1338.jpg',
#         'dataset/valid/with_mask/with_mask_1339.jpg',
#         'dataset/valid/with_mask/with_mask_134.jpg',
#         'dataset/valid/with_mask/with_mask_1340.jpg',
#         'dataset/valid/with_mask/with_mask_1341.jpg',
#         'dataset/valid/with_mask/with_mask_1342.jpg',
#         'dataset/valid/with_mask/with_mask_1343.jpg',
#         'dataset/valid/with_mask/with_mask_1344.jpg',
#         'dataset/valid/with_mask/with_mask_1345.jpg',
#         'dataset/valid/with_mask/with_mask_1346.jpg',
#         'dataset/valid/with_mask/with_mask_1347.jpg',
#         'dataset/valid/with_mask/with_mask_1348.jpg',
#         'dataset/valid/with_mask/with_mask_1349.jpg',
#         'dataset/valid/with_mask/with_mask_135.jpg',
#         'dataset/valid/with_mask/with_mask_1350.jpg',
#         'dataset/valid/with_mask/with_mask_1351.jpg',
#         'dataset/valid/with_mask/with_mask_1352.jpg',
#         'dataset/valid/with_mask/with_mask_1353.jpg',
#         'dataset/valid/with_mask/with_mask_1354.jpg',
#         'dataset/valid/with_mask/with_mask_1355.jpg',
#         'dataset/valid/with_mask/with_mask_1356.jpg',
#         'dataset/valid/with_mask/with_mask_1357.jpg',
#         'dataset/valid/with_mask/with_mask_1358.jpg',
#         'dataset/valid/with_mask/with_mask_1359.jpg',
#         'dataset/valid/with_mask/with_mask_136.jpg',
#         'dataset/valid/with_mask/with_mask_1360.jpg',
#         'dataset/valid/with_mask/with_mask_1361.jpg',
#         'dataset/valid/with_mask/with_mask_1362.jpg',
#         'dataset/valid/with_mask/with_mask_1363.jpg',
#         'dataset/valid/with_mask/with_mask_1364.jpg',
#         'dataset/valid/with_mask/with_mask_1365.jpg',
#         'dataset/valid/with_mask/with_mask_1366.jpg',
#         'dataset/valid/with_mask/with_mask_1367.jpg',
#         'dataset/valid/with_mask/with_mask_1368.jpg',
#         'dataset/valid/with_mask/with_mask_1369.jpg',
#         'dataset/valid/with_mask/with_mask_137.jpg',
#         'dataset/valid/with_mask/with_mask_1370.jpg',
#         'dataset/valid/with_mask/with_mask_1371.jpg',
#         'dataset/valid/with_mask/with_mask_1372.jpg',
#         'dataset/valid/with_mask/with_mask_1373.jpg',
#         'dataset/valid/with_mask/with_mask_1374.jpg',
#         'dataset/valid/with_mask/with_mask_1375.jpg',
#         'dataset/valid/with_mask/with_mask_1376.jpg',
#         'dataset/valid/with_mask/with_mask_1377.jpg',
#         'dataset/valid/with_mask/with_mask_1378.jpg',
#         'dataset/valid/with_mask/with_mask_1379.jpg',
#         'dataset/valid/with_mask/with_mask_138.jpg',
#         'dataset/valid/with_mask/with_mask_1380.jpg',
#         'dataset/valid/with_mask/with_mask_1381.jpg',
#         'dataset/valid/with_mask/with_mask_1382.jpg',
#         'dataset/valid/with_mask/with_mask_1383.jpg',
#         'dataset/valid/with_mask/with_mask_1384.jpg',
#         'dataset/valid/with_mask/with_mask_1385.jpg',
#         'dataset/valid/with_mask/with_mask_1386.jpg',
#         'dataset/valid/with_mask/with_mask_1387.jpg',
#         'dataset/valid/with_mask/with_mask_1388.jpg',
#         'dataset/valid/with_mask/with_mask_1389.jpg',
#         'dataset/valid/with_mask/with_mask_139.jpg',
#         'dataset/valid/with_mask/with_mask_1390.jpg',
#         'dataset/valid/with_mask/with_mask_1391.jpg',
#         'dataset/valid/with_mask/with_mask_1392.jpg',
#         'dataset/valid/with_mask/with_mask_1393.jpg',
#         'dataset/valid/with_mask/with_mask_1394.jpg',
#         'dataset/valid/with_mask/with_mask_1395.jpg',
#         'dataset/valid/with_mask/with_mask_1396.jpg',
#         'dataset/valid/with_mask/with_mask_1397.jpg',
#         'dataset/valid/with_mask/with_mask_1398.jpg',
#         'dataset/valid/with_mask/with_mask_1399.jpg',
#         'dataset/valid/with_mask/with_mask_14.jpg',
#         'dataset/valid/with_mask/with_mask_140.jpg',
#         'dataset/valid/with_mask/with_mask_1400.jpg',
#         'dataset/valid/with_mask/with_mask_1401.jpg',
#         'dataset/valid/with_mask/with_mask_1402.jpg',
#         'dataset/valid/with_mask/with_mask_1403.jpg',
#         'dataset/valid/with_mask/with_mask_1404.jpg',
#         'dataset/valid/with_mask/with_mask_1405.jpg',
#         'dataset/valid/with_mask/with_mask_1406.jpg',
#         'dataset/valid/with_mask/with_mask_1407.jpg',
#         'dataset/valid/with_mask/with_mask_1408.jpg',
#         'dataset/valid/with_mask/with_mask_1409.jpg',
#         'dataset/valid/with_mask/with_mask_141.jpg',
#         'dataset/valid/with_mask/with_mask_1410.jpg',
#         'dataset/valid/with_mask/with_mask_1411.jpg',
#         'dataset/valid/with_mask/with_mask_1412.jpg',
#         'dataset/valid/with_mask/with_mask_1413.jpg',
#         'dataset/valid/with_mask/with_mask_1414.jpg',
#         'dataset/valid/with_mask/with_mask_1415.jpg',
#         'dataset/valid/with_mask/with_mask_1416.jpg',
#         'dataset/valid/with_mask/with_mask_1417.jpg',
#         'dataset/valid/with_mask/with_mask_1418.jpg',
#         'dataset/valid/with_mask/with_mask_1419.jpg',
#         'dataset/valid/with_mask/with_mask_142.jpg',
#         'dataset/valid/with_mask/with_mask_1420.jpg',
#         'dataset/valid/with_mask/with_mask_1421.jpg',
#         'dataset/valid/with_mask/with_mask_1422.jpg',
#         'dataset/valid/with_mask/with_mask_1423.jpg',
#         'dataset/valid/with_mask/with_mask_1424.jpg',
#         'dataset/valid/with_mask/with_mask_1425.jpg',
#         'dataset/valid/with_mask/with_mask_1426.jpg',
#         'dataset/valid/with_mask/with_mask_1427.jpg',
#         'dataset/valid/with_mask/with_mask_1428.jpg',
#         'dataset/valid/with_mask/with_mask_1429.jpg',
#         'dataset/valid/with_mask/with_mask_143.jpg',
#         'dataset/valid/with_mask/with_mask_1430.jpg',
#         'dataset/valid/with_mask/with_mask_1431.jpg',
#         'dataset/valid/with_mask/with_mask_1432.jpg',
#         'dataset/valid/with_mask/with_mask_1433.jpg',
#         'dataset/valid/with_mask/with_mask_1434.jpg',
#         'dataset/valid/with_mask/with_mask_1435.jpg',
#         'dataset/valid/with_mask/with_mask_1436.jpg',
#         'dataset/valid/with_mask/with_mask_1437.jpg',
#         'dataset/valid/with_mask/with_mask_1438.jpg',
#         'dataset/valid/with_mask/with_mask_1439.jpg',
#         'dataset/valid/with_mask/with_mask_144.jpg',
#         'dataset/valid/with_mask/with_mask_1440.jpg',
#         'dataset/valid/with_mask/with_mask_1441.jpg',
#         'dataset/valid/with_mask/with_mask_1442.jpg',
#         'dataset/valid/with_mask/with_mask_1443.jpg',
#         'dataset/valid/with_mask/with_mask_1444.jpg',
#         'dataset/valid/with_mask/with_mask_1445.jpg',
#         'dataset/valid/with_mask/with_mask_1446.jpg',
#         'dataset/valid/with_mask/with_mask_1447.jpg',
#         'dataset/valid/with_mask/with_mask_1448.jpg',
#         'dataset/valid/with_mask/with_mask_1449.jpg',
#         'dataset/valid/with_mask/with_mask_145.jpg',
#         'dataset/valid/with_mask/with_mask_1450.jpg',
#         'dataset/valid/with_mask/with_mask_1451.jpg',
#         'dataset/valid/with_mask/with_mask_1452.jpg',
#         'dataset/valid/with_mask/with_mask_1453.jpg',
#         'dataset/valid/with_mask/with_mask_1454.jpg',
#         'dataset/valid/with_mask/with_mask_1455.jpg',
#         'dataset/valid/with_mask/with_mask_1456.jpg',
#         'dataset/valid/with_mask/with_mask_1457.jpg',
#         'dataset/valid/with_mask/with_mask_1458.jpg',
#         'dataset/valid/with_mask/with_mask_1459.jpg',
#         'dataset/valid/with_mask/with_mask_146.jpg',
#         'dataset/valid/with_mask/with_mask_1460.jpg',
#         'dataset/valid/with_mask/with_mask_1461.jpg',
#         'dataset/valid/with_mask/with_mask_1462.jpg',
#         'dataset/valid/with_mask/with_mask_1463.jpg',
#         'dataset/valid/with_mask/with_mask_1464.jpg',
#         'dataset/valid/with_mask/with_mask_1465.jpg',
#         'dataset/valid/with_mask/with_mask_1466.jpg',
#         'dataset/valid/with_mask/with_mask_1467.jpg',
#         'dataset/valid/with_mask/with_mask_1468.jpg',
#         'dataset/valid/with_mask/with_mask_1469.jpg',
#         'dataset/valid/with_mask/with_mask_147.jpg',
#         'dataset/valid/with_mask/with_mask_1470.jpg',
#         'dataset/valid/with_mask/with_mask_1471.jpg',
#         'dataset/valid/with_mask/with_mask_1472.jpg',
#         'dataset/valid/with_mask/with_mask_1473.jpg',
#         'dataset/valid/with_mask/with_mask_1474.jpg',
#         'dataset/valid/with_mask/with_mask_1475.jpg',
#         'dataset/valid/with_mask/with_mask_1476.jpg',
#         'dataset/valid/with_mask/with_mask_1477.jpg',
#         'dataset/valid/with_mask/with_mask_1478.jpg',
#         'dataset/valid/with_mask/with_mask_1479.jpg',
#         'dataset/valid/with_mask/with_mask_148.jpg',
#         'dataset/valid/with_mask/with_mask_1480.jpg',
#         'dataset/valid/with_mask/with_mask_1481.jpg',
#         'dataset/valid/with_mask/with_mask_1482.jpg',
#         'dataset/valid/with_mask/with_mask_1483.jpg',
#         'dataset/valid/with_mask/with_mask_1484.jpg',
#         'dataset/valid/with_mask/with_mask_1485.jpg',
#         'dataset/valid/with_mask/with_mask_1486.jpg',
#         'dataset/valid/with_mask/with_mask_1487.jpg',
#         'dataset/valid/with_mask/with_mask_1488.jpg',
#         'dataset/valid/with_mask/with_mask_1489.jpg',
#         'dataset/valid/with_mask/with_mask_149.jpg',
#         'dataset/valid/with_mask/with_mask_1490.jpg',
#         'dataset/valid/with_mask/with_mask_1491.jpg',
#         'dataset/valid/with_mask/with_mask_1492.jpg',
#         'dataset/valid/with_mask/with_mask_1493.jpg',
#         'dataset/valid/with_mask/with_mask_1494.jpg',
#         'dataset/valid/with_mask/with_mask_1495.jpg',
#         'dataset/valid/with_mask/with_mask_1496.jpg',
#         'dataset/valid/with_mask/with_mask_1497.jpg',
#         'dataset/valid/with_mask/with_mask_1498.jpg',
#         'dataset/valid/with_mask/with_mask_1499.jpg',
#         'dataset/valid/with_mask/with_mask_15.jpg',
#         'dataset/valid/with_mask/with_mask_150.jpg',
#         'dataset/valid/with_mask/with_mask_1500.jpg',
#         'dataset/valid/with_mask/with_mask_1501.jpg',
#         'dataset/valid/with_mask/with_mask_1502.jpg',
#         'dataset/valid/with_mask/with_mask_1503.jpg',
#         'dataset/valid/with_mask/with_mask_1504.jpg',
#         'dataset/valid/with_mask/with_mask_1505.jpg',
#         'dataset/valid/with_mask/with_mask_1506.jpg',
#         'dataset/valid/with_mask/with_mask_1507.jpg',
#         'dataset/valid/with_mask/with_mask_1508.jpg',
#         'dataset/valid/with_mask/with_mask_1509.jpg',
#         'dataset/valid/with_mask/with_mask_151.jpg',
#         'dataset/valid/with_mask/with_mask_1510.jpg',
#         'dataset/valid/with_mask/with_mask_1511.jpg',
#         'dataset/valid/with_mask/with_mask_1512.jpg',
#         'dataset/valid/with_mask/with_mask_1513.jpg',
#         'dataset/valid/with_mask/with_mask_1514.jpg',
#         'dataset/valid/with_mask/with_mask_1515.jpg',
#         'dataset/valid/with_mask/with_mask_1516.jpg',
#         'dataset/valid/with_mask/with_mask_1517.jpg',
#         'dataset/valid/with_mask/with_mask_1518.jpg',
#         'dataset/valid/with_mask/with_mask_1519.jpg',
#         'dataset/valid/with_mask/with_mask_152.jpg',
#         'dataset/valid/with_mask/with_mask_1520.jpg',
#         'dataset/valid/with_mask/with_mask_1521.jpg',
#         'dataset/valid/with_mask/with_mask_1522.jpg',
#         'dataset/valid/with_mask/with_mask_1523.jpg',
#         'dataset/valid/with_mask/with_mask_1524.jpg',
#         'dataset/valid/with_mask/with_mask_1525.jpg',
#         'dataset/valid/with_mask/with_mask_1526.jpg',
#         'dataset/valid/with_mask/with_mask_1527.jpg',
#         'dataset/valid/with_mask/with_mask_1528.jpg',
#         'dataset/valid/with_mask/with_mask_1529.jpg',
#         'dataset/valid/with_mask/with_mask_153.jpg',
#         'dataset/valid/with_mask/with_mask_1530.jpg',
#         'dataset/valid/with_mask/with_mask_1531.jpg',
#         'dataset/valid/with_mask/with_mask_1532.jpg',
#         'dataset/valid/with_mask/with_mask_1533.jpg',
#         'dataset/valid/with_mask/with_mask_1534.jpg',
#         'dataset/valid/with_mask/with_mask_1535.jpg',
#         'dataset/valid/with_mask/with_mask_1536.jpg',
#         'dataset/valid/with_mask/with_mask_1537.jpg',
#         'dataset/valid/with_mask/with_mask_1538.jpg',
#         'dataset/valid/with_mask/with_mask_1539.jpg',
#         'dataset/valid/with_mask/with_mask_154.jpg',
#         'dataset/valid/with_mask/with_mask_1540.jpg',
#         'dataset/valid/with_mask/with_mask_1541.jpg',
#         'dataset/valid/with_mask/with_mask_1542.jpg',
#         'dataset/valid/with_mask/with_mask_1543.jpg',
#         'dataset/valid/with_mask/with_mask_1544.jpg',
#         'dataset/valid/with_mask/with_mask_1545.jpg',
#         'dataset/valid/with_mask/with_mask_1546.jpg',
#         'dataset/valid/with_mask/with_mask_1547.jpg',
#         'dataset/valid/with_mask/with_mask_1548.jpg',
#         'dataset/valid/with_mask/with_mask_1549.jpg',
#         'dataset/valid/with_mask/with_mask_155.jpg',
#         'dataset/valid/with_mask/with_mask_1550.jpg',
#         'dataset/valid/with_mask/with_mask_1551.jpg',
#         'dataset/valid/with_mask/with_mask_1552.jpg',
#         'dataset/valid/with_mask/with_mask_1553.jpg',
#         'dataset/valid/with_mask/with_mask_1554.jpg',
#         'dataset/valid/with_mask/with_mask_1555.jpg',
#         'dataset/valid/with_mask/with_mask_1556.jpg',
#         'dataset/valid/without_mask/without_mask_1.jpg',
#         'dataset/valid/without_mask/without_mask_10.jpg',
#         'dataset/valid/without_mask/without_mask_100.jpg',
#         'dataset/valid/without_mask/without_mask_1000.jpg',
#         'dataset/valid/without_mask/without_mask_1001.jpg',
#         'dataset/valid/without_mask/without_mask_1002.jpg',
#         'dataset/valid/without_mask/without_mask_1003.jpg',
#         'dataset/valid/without_mask/without_mask_1004.jpg',
#         'dataset/valid/without_mask/without_mask_1005.jpg',
#         'dataset/valid/without_mask/without_mask_1006.jpg',
#         'dataset/valid/without_mask/without_mask_1007.jpg',
#         'dataset/valid/without_mask/without_mask_1008.jpg',
#         'dataset/valid/without_mask/without_mask_1009.jpg',
#         'dataset/valid/without_mask/without_mask_101.jpg',
#         'dataset/valid/without_mask/without_mask_1010.jpg',
#         'dataset/valid/without_mask/without_mask_1011.jpg',
#         'dataset/valid/without_mask/without_mask_1012.jpg',
#         'dataset/valid/without_mask/without_mask_1013.jpg',
#         'dataset/valid/without_mask/without_mask_1014.jpg',
#         'dataset/valid/without_mask/without_mask_1015.jpg',
#         'dataset/valid/without_mask/without_mask_1016.jpg',
#         'dataset/valid/without_mask/without_mask_1017.jpg',
#         'dataset/valid/without_mask/without_mask_1018.jpg',
#         'dataset/valid/without_mask/without_mask_1019.jpg',
#         'dataset/valid/without_mask/without_mask_102.jpg',
#         'dataset/valid/without_mask/without_mask_1020.jpg',
#         'dataset/valid/without_mask/without_mask_1021.jpg',
#         'dataset/valid/without_mask/without_mask_1022.jpg',
#         'dataset/valid/without_mask/without_mask_1023.jpg',
#         'dataset/valid/without_mask/without_mask_1024.jpg',
#         'dataset/valid/without_mask/without_mask_1025.jpg',
#         'dataset/valid/without_mask/without_mask_1026.jpg',
#         'dataset/valid/without_mask/without_mask_1027.jpg',
#         'dataset/valid/without_mask/without_mask_1028.jpg',
#         'dataset/valid/without_mask/without_mask_1029.jpg',
#         'dataset/valid/without_mask/without_mask_103.jpg',
#         'dataset/valid/without_mask/without_mask_1030.jpg',
#         'dataset/valid/without_mask/without_mask_1031.jpg',
#         'dataset/valid/without_mask/without_mask_1032.jpg',
#         'dataset/valid/without_mask/without_mask_1033.jpg',
#         'dataset/valid/without_mask/without_mask_1034.jpg',
#         'dataset/valid/without_mask/without_mask_1035.jpg',
#         'dataset/valid/without_mask/without_mask_1036.jpg',
#         'dataset/valid/without_mask/without_mask_1037.jpg',
#         'dataset/valid/without_mask/without_mask_1038.jpg',
#         'dataset/valid/without_mask/without_mask_1039.jpg',
#         'dataset/valid/without_mask/without_mask_104.jpg',
#         'dataset/valid/without_mask/without_mask_1040.jpg',
#         'dataset/valid/without_mask/without_mask_1041.jpg',
#         'dataset/valid/without_mask/without_mask_1042.jpg',
#         'dataset/valid/without_mask/without_mask_1043.jpg',
#         'dataset/valid/without_mask/without_mask_1044.jpg',
#         'dataset/valid/without_mask/without_mask_1045.jpg',
#         'dataset/valid/without_mask/without_mask_1046.jpg',
#         'dataset/valid/without_mask/without_mask_1047.jpg',
#         'dataset/valid/without_mask/without_mask_1048.jpg',
#         'dataset/valid/without_mask/without_mask_1049.jpg',
#         'dataset/valid/without_mask/without_mask_105.jpg',
#         'dataset/valid/without_mask/without_mask_1050.jpg',
#         'dataset/valid/without_mask/without_mask_1051.jpg',
#         'dataset/valid/without_mask/without_mask_1052.jpg',
#         'dataset/valid/without_mask/without_mask_1053.jpg',
#         'dataset/valid/without_mask/without_mask_1054.jpg',
#         'dataset/valid/without_mask/without_mask_1055.jpg',
#         'dataset/valid/without_mask/without_mask_1056.jpg',
#         'dataset/valid/without_mask/without_mask_1057.jpg',
#         'dataset/valid/without_mask/without_mask_1058.jpg',
#         'dataset/valid/without_mask/without_mask_1059.jpg',
#         'dataset/valid/without_mask/without_mask_106.jpg',
#         'dataset/valid/without_mask/without_mask_1060.jpg',
#         'dataset/valid/without_mask/without_mask_1061.jpg',
#         'dataset/valid/without_mask/without_mask_1062.jpg',
#         'dataset/valid/without_mask/without_mask_1063.jpg',
#         'dataset/valid/without_mask/without_mask_1064.jpg',
#         'dataset/valid/without_mask/without_mask_1065.jpg',
#         'dataset/valid/without_mask/without_mask_1066.jpg',
#         'dataset/valid/without_mask/without_mask_1067.jpg',
#         'dataset/valid/without_mask/without_mask_1068.jpg',
#         'dataset/valid/without_mask/without_mask_1069.jpg',
#         'dataset/valid/without_mask/without_mask_107.jpg',
#         'dataset/valid/without_mask/without_mask_1070.jpg',
#         'dataset/valid/without_mask/without_mask_1071.jpg',
#         'dataset/valid/without_mask/without_mask_1072.jpg',
#         'dataset/valid/without_mask/without_mask_1073.jpg',
#         'dataset/valid/without_mask/without_mask_1074.jpg',
#         'dataset/valid/without_mask/without_mask_1075.jpg',
#         'dataset/valid/without_mask/without_mask_1076.jpg',
#         'dataset/valid/without_mask/without_mask_1077.jpg',
#         'dataset/valid/without_mask/without_mask_1078.jpg',
#         'dataset/valid/without_mask/without_mask_1079.jpg',
#         'dataset/valid/without_mask/without_mask_108.jpg',
#         'dataset/valid/without_mask/without_mask_1080.jpg',
#         'dataset/valid/without_mask/without_mask_1081.jpg',
#         'dataset/valid/without_mask/without_mask_1082.jpg',
#         'dataset/valid/without_mask/without_mask_1083.jpg',
#         'dataset/valid/without_mask/without_mask_1084.jpg',
#         'dataset/valid/without_mask/without_mask_1085.jpg',
#         'dataset/valid/without_mask/without_mask_1086.jpg',
#         'dataset/valid/without_mask/without_mask_1087.jpg',
#         'dataset/valid/without_mask/without_mask_1088.jpg',
#         'dataset/valid/without_mask/without_mask_1089.jpg',
#         'dataset/valid/without_mask/without_mask_109.jpg',
#         'dataset/valid/without_mask/without_mask_1090.jpg',
#         'dataset/valid/without_mask/without_mask_1091.jpg',
#         'dataset/valid/without_mask/without_mask_1092.jpg',
#         'dataset/valid/without_mask/without_mask_1093.jpg',
#         'dataset/valid/without_mask/without_mask_1094.jpg',
#         'dataset/valid/without_mask/without_mask_1095.jpg',
#         'dataset/valid/without_mask/without_mask_1096.jpg',
#         'dataset/valid/without_mask/without_mask_1097.jpg',
#         'dataset/valid/without_mask/without_mask_1098.jpg',
#         'dataset/valid/without_mask/without_mask_1099.jpg',
#         'dataset/valid/without_mask/without_mask_11.jpg',
#         'dataset/valid/without_mask/without_mask_110.jpg',
#         'dataset/valid/without_mask/without_mask_1100.jpg',
#         'dataset/valid/without_mask/without_mask_1101.jpg',
#         'dataset/valid/without_mask/without_mask_1102.jpg',
#         'dataset/valid/without_mask/without_mask_1103.jpg',
#         'dataset/valid/without_mask/without_mask_1104.jpg',
#         'dataset/valid/without_mask/without_mask_1105.jpg',
#         'dataset/valid/without_mask/without_mask_1106.jpg',
#         'dataset/valid/without_mask/without_mask_1107.jpg',
#         'dataset/valid/without_mask/without_mask_1108.jpg',
#         'dataset/valid/without_mask/without_mask_1109.jpg',
#         'dataset/valid/without_mask/without_mask_111.jpg',
#         'dataset/valid/without_mask/without_mask_1110.jpg',
#         'dataset/valid/without_mask/without_mask_1111.jpg',
#         'dataset/valid/without_mask/without_mask_1112.jpg',
#         'dataset/valid/without_mask/without_mask_1113.jpg',
#         'dataset/valid/without_mask/without_mask_1114.jpg',
#         'dataset/valid/without_mask/without_mask_1115.jpg',
#         'dataset/valid/without_mask/without_mask_1116.jpg',
#         'dataset/valid/without_mask/without_mask_1117.jpg',
#         'dataset/valid/without_mask/without_mask_1118.jpg',
#         'dataset/valid/without_mask/without_mask_1119.jpg',
#         'dataset/valid/without_mask/without_mask_112.jpg',
#         'dataset/valid/without_mask/without_mask_1120.jpg',
#         'dataset/valid/without_mask/without_mask_1121.jpg',
#         'dataset/valid/without_mask/without_mask_1122.jpg',
#         'dataset/valid/without_mask/without_mask_1123.jpg',
#         'dataset/valid/without_mask/without_mask_1124.jpg',
#         'dataset/valid/without_mask/without_mask_1125.jpg',
#         'dataset/valid/without_mask/without_mask_1126.jpg',
#         'dataset/valid/without_mask/without_mask_1127.jpg',
#         'dataset/valid/without_mask/without_mask_1128.jpg',
#         'dataset/valid/without_mask/without_mask_1129.jpg',
#         'dataset/valid/without_mask/without_mask_113.jpg',
#         'dataset/valid/without_mask/without_mask_1130.jpg',
#         'dataset/valid/without_mask/without_mask_1131.jpg',
#         'dataset/valid/without_mask/without_mask_1132.jpg',
#         'dataset/valid/without_mask/without_mask_1133.jpg',
#         'dataset/valid/without_mask/without_mask_1134.jpg',
#         'dataset/valid/without_mask/without_mask_1135.jpg'], dtype='<U48'))

# %%
y_train,y_test
# Out:
# (array(['with_mask', 'with_mask', 'with_mask', ..., 'without_mask',
#         'without_mask', 'without_mask'], dtype='<U12'),
#  array(['with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'with_mask', 'with_mask', 'with_mask', 'with_mask', 'with_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask', 'without_mask', 'without_mask', 'without_mask',
#         'without_mask'], dtype='<U12'))

# %% [markdown]
# ### Langkah 4 : Membangun Neural Network

# %% [markdown]
# kami membuat Convoutional Neural Network (CNN) dengan Keras. Disini kami menggunakan 2 unit Dense layer  dengan aktivasi Softmax sebagai node keluaran karena kami ingin 2 buah keluaran array agar lebih mudah menerima informasi yang diprediksi.

# %%
# Create model structure
model = keras.Sequential([
    # Input Layer
    keras.layers.Conv2D(input_shape=(224,224,3),filters=32,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPooling2D(),
    
    # Hidden Layer
    keras.layers.Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPooling2D(),
    keras.layers.Conv2D(input_shape=(224,224,3),filters=128,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPooling2D(),
    keras.layers.Flatten(),
    keras.layers.Dense(128),
    keras.layers.Activation('relu'),
    
    # Output Layer
    keras.layers.Dense(2),
    keras.layers.Activation('softmax')
])

# Compile model
model.compile(loss='categorical_crossentropy',optimizer=keras.optimizers.Adam(),metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 86528)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               11075712
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 11,169,218
# Trainable params: 11,169,218
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Langkah 5: Model Pelatihan

# %% [markdown]
# Proses pelatihan berjalan selama 50 epoch. kami juga menggunakan penghentian awal agar proses pelatihan dapat dihentikan secara otomatis jika model tidak membaik selama 3 epcoh. Ini juga digunakan untuk menghindari overfitting.

# %%
# buat panggilan balik penghentian awal
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',patience=3)

# Simpan riwayat model menjadi variabel
history = model.fit(train_data,validation_data = valid_data,validation_freq=1,epochs = 50,callbacks = [early_stopping],verbose = 1,)

# Plot model training history
def plot_history():
    plt.plot(history.history['acc'],label='acc')
    plt.plot(history.history['val_acc'],label='val_acc')
    plt.plot(history.history['loss'],label='loss')
    plt.plot(history.history['val_loss'],label='val_loss')
    plt.legend()
    plt.title('Training History')
    plt.xlabel('epoch')
    plt.ylabel('value')
    plt.tight_layout()
    plt.grid(True)
    plt.savefig('output/training_history-softmax-adam.jpg')
    plt.show()

plot_history()
# Out:
# Epoch 1/50
# 212/212 [==============================] - 284s 1s/step - loss: 0.3515 - acc: 0.8544 - val_loss: 0.3027 - val_acc: 0.8900
# Epoch 2/50
# 212/212 [==============================] - 275s 1s/step - loss: 0.2178 - acc: 0.9086 - val_loss: 0.1777 - val_acc: 0.9237
# Epoch 3/50
# 212/212 [==============================] - 379s 2s/step - loss: 0.1692 - acc: 0.9305 - val_loss: 0.1289 - val_acc: 0.9521
# Epoch 4/50
# 212/212 [==============================] - 308s 1s/step - loss: 0.1154 - acc: 0.9588 - val_loss: 0.1358 - val_acc: 0.9573
# Epoch 5/50
# 212/212 [==============================] - 264s 1s/step - loss: 0.0740 - acc: 0.9730 - val_loss: 0.1649 - val_acc: 0.9495
# Epoch 6/50
# 212/212 [==============================] - 268s 1s/step - loss: 0.0644 - acc: 0.9786 - val_loss: 0.1629 - val_acc: 0.9573

# %%
import pandas as pd
df =pd.DataFrame.from_dict(history.history)
print(df.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b514fd4f0539> in <module>
#       1 import pandas as pd
# ----> 2 df =pd.DataFrame.from_dict(history.history)
#       3 print(df.mean())
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### Langkah 6: Demonstrasi

# %% [markdown]
# kami melakukan demonstrasi menggunakan 12 foto. berikut hasil model yang dapat memprediksi dengan nilai probabilitas tertentu.

# %%
def predict(unseen_image = []):
    test_data = batchData(unseen_image,for_test=True)
    prediction = model.predict(test_data)

    for image,pred in zip(unseen_image,prediction):
        fig,axes = plt.subplots(nrows=1,ncols=2)
        axes[0].imshow(processImage(image))
        axes[0].axis(False)
        axes[0].set_title('Actual Image')

        axes[1].bar([0,1],pred)
        axes[1].set_xticks([0,1])
        axes[1].set_xticklabels(['with_mask','without_mask'])
        axes[1].set_title('Prediction Probability')
        plt.savefig(f'output/prediction_test_{image.split("/")[-1].split(".")[0]}.jpg')
        plt.show()
                    
predict(list(map(lambda x : f'test/{x}', os.listdir('test'))))

# %% [markdown]
# menyimpan model ke dalam file h5

# %%
model.save('output/face_mask_ai.h5')

# %% [markdown]
# #### Parameter yang akan di analisis
# variasi aktivasi : relu-relu-softmax, relu-relu-sigmoid
#
# variasi optimizer :  Adam dan AdaDelta,

# %%
TP = 9
TN = 2
F = 1
(TP+TN)/(TP+TN+F)*100
# Out:
# 91.66666666666666

# %%
import cv2
import datetime
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
keras = tf.keras

# Blit function to put text in video
def blit(text,frame,color,position=(100, 100)):
    cv2.putText(frame, text, position, cv2.FONT_HERSHEY_SIMPLEX, 2, color, 4, cv2.LINE_4)


model = keras.models.load_model('output/face_mask_ai.h5') # Loading Saved NN Model
input_video = 'Mask Detection Test Video.mp4' # Video path / filename


# Get video resolution
videoCapture = cv2.VideoCapture(input_video)
fps = videoCapture.get(cv2.CAP_PROP_FPS)
size = (int(videoCapture.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(videoCapture.get(cv2.CAP_PROP_FRAME_HEIGHT)))

# Write video to .avi
today = str(datetime.datetime.today()).split(' ')
today_time = '-'.join(today[1].split(':')[:-1])

video_name = f'output-{today[0]}-{today_time}.avi'
fourcc = cv2.VideoWriter_fourcc(*'XVID')
videoWriter = cv2.VideoWriter(video_name,fourcc, fps, size)

print(f'Video files name : {video_name}')
print(f'Video fps : {fps}')
print(f'Video size : {size}')
print('Program is working. Please be patient...')

# Run the AI
first_time = True
while True:
    res,frame = videoCapture.read()
    if res:
        img = cv2.resize(frame, (224,224), interpolation = cv2.INTER_AREA)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        prediction = model.predict(np.expand_dims(img,axis=0))

        blit(f'Prediction Probability',frame,(255,255,255),(100,100))
        blit(f'Wearing mask : {prediction[0][0]}',frame,(0, 255, 0),(100,200))
        blit(f'Not wearing mask : {prediction[0][1]}',frame,(0, 0, 255),(100,300))

        if first_time:
            plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            plt.axis(False)
            plt.title('First Video Frame')
            plt.show()
            first_time = False
        
        # Write detected frame by frame
        videoWriter.write(frame)
    else:
        break

videoCapture.release()
videoWriter.release()
cv2.destroyAllWindows()

print(f'Finished. Video exported to {video_name}')
# Out:
# Video files name : output-2021-04-16-09-44.avi
# Video fps : 25.0
# Video size : (720, 404)
# Program is working. Please be patient...
# Finished. Video exported to output-2021-04-16-09-44.avi

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
